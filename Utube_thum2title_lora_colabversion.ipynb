# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
from pathlib import Path

# Colab용 루트 경로
ROOT = Path("/content/drive/MyDrive/yt")

print("DATA_DIR:", ROOT)
print("존재 여부:", ROOT.exists())
# Out:
# DATA_DIR: /content/drive/MyDrive/yt
# 존재 여부: True

# %% [markdown]
# ---
# 금일 수집 데이터 merge

# %%
import os
from pathlib import Path

folder = ROOT / "Utube_data" / "data_collect" / "Utube_data" / "data_collect" / "collect"

csv_files = list(folder.glob('*.csv'))

file_names = [f.name for f in csv_files]
file_data = str(file_names).split('-')[0]
file_data[-4:]
# Out:
# '1208'

# %%
def collect_merge_df(root):
    import os
    from pathlib import Path
    import pandas as pd

    folder = Path(root)
    csv_files = list(folder.glob('*.csv'))

    if not csv_files:
        print(f"[WARN] No CSV files found in the specified folder: {folder}")
        return pd.DataFrame() # Return empty DataFrame if no files

    file_names = [f.name for f in csv_files]
    # Extract date part assuming format like 'UtubeDataYYYY-MM-DD.csv' or similar.
    # Safely get the date part.
    file_data = 'merged'
    if file_names:
        try:
            # Assuming filename format is 'UtubeDataYYYYMMDD-X.csv' or 'UtubeDataYYYYMMDD.csv'
            first_file_name_part = file_names[0].split('-')[0]
            # Extracting last 4 characters, assuming it's the year or date suffix
            file_data = first_file_name_part[-4:]
        except IndexError:
            print(f"[WARN] Could not parse date from filename: {file_names[0]}. Using 'merged' as fallback.")

    df_list = []

    for file in csv_files:
        temp_df = pd.read_csv(file)
        df_list.append(temp_df)

    if not df_list:
        print("[WARN] No data frames to concatenate after reading files.")
        return pd.DataFrame() # Return empty DataFrame if no data

    merged_df = pd.concat(df_list, ignore_index=True)
    merged_df = merged_df.sort_values('created_at')
    merged_df = merged_df.drop_duplicates(subset='videoId' ,keep='last')

    # Construct the output directory path relative to ROOT for Google Drive
    # Assuming ROOT is accessible globally as defined in a previous cell.
    global ROOT # Declare ROOT as global if it's not passed as an argument and used here
    output_dir = ROOT / "Utube_data" / "data"
    os.makedirs(output_dir, exist_ok=True) # Create directory if it doesn't exist

    output_path = output_dir / f'youtubedata-{file_data}.csv'
    merged_df.to_csv(output_path, index=False)

    return merged_df # Return the DataFrame, not the result of to_csv

# %%
collect_merge_df(root=ROOT / "Utube_data" / "data_collect" / "Utube_data" / "data_collect" / "collect")
# Out:
#      id      videoId                                              title  \
# 0   180  hitC3ZG4dTI                           500~600만원대 중고차의 안타까운 현실😇
# 1   181  QZFW_JL8E40  옵션 많은 베스트 셀렉션II 2천만 원대 특가 2021년형 더K9 3.8 4륜 컬러...
# 2   182  pMZtk7XNc1Y                                   눈길 운전 사고 방지용 아이템
# 3   183  0b2-7bcRvI0  화사가 말하는 좋은 이별 (Good Goodbye - 화사) #노래 #kpop #m...
# 4   184  jDiAdsAMoyA  #funny #cat #pets #animals #comedy #celanapend...
# 5   185  mz_SijmojfU  감자튀기는 고양이 #cat #크림냥 #cute #pets #animals #funn...
# 6   186  s2S0jPX4BI4  🇺🇸 💥 Impossible! Tallest Golfer Pulls Off Jaw-...
# 7   187  e5UNL0OHhdo  얼음의 숨결 – 시네마틱 댄스8K  리얼리즘, 얼음 위에 피어난 감정의 예술#8k ...
# 8   188  wT68vdBmhVU  얼음의 숨결 – 시네마틱 댄스8K 리얼리즘, 얼음 위에 피어난 감정의 예술#8k리얼...
# 9   189  nf5H8sc_XkY  얼음의 숨결 – 시네마틱 댄스8K  리얼리즘, 얼음 위에 피어난 감정의 예술#8k ...
# 10  190  F9Bfzr8J2do  얼음의 숨결 – 시네마틱 댄스8K  리얼리즘, 얼음 위에 피어난 감정의 예술#8k ...
# 11  191  ru1DdndLYb0  얼음의 숨결 – 시네마틱 댄스8K  리얼리즘, 얼음 위에 피어난 감정의 예술#8k ...
# ...

# %% [markdown]
# ---
# 전체 수집 데이터 merge

# %%
def merge_df(root):
    import os
    from pathlib import Path
    import pandas as pd

    folder = Path(root)
    csv_files = list(folder.glob('*.csv'))

    df_list = []

    for file in csv_files:
        temp_df = pd.read_csv(file)
        df_list.append(temp_df)

    merged_df = pd.concat(df_list, ignore_index=True)
    merged_df = merged_df.sort_values('created_at')
    merged_df = merged_df.drop_duplicates(subset='videoId' ,keep='last')

    return merged_df

# %%
merge_df = merge_df(ROOT / 'Utube_data' / 'data')

from datetime import datetime

today = datetime.now().strftime("%Y%m%d")

# Ensure the directory exists before saving
import os
os.makedirs(ROOT / 'Utube_data', exist_ok=True)

merge_df.to_csv(ROOT / f"Utube_data/youtube_merge_{today}.csv", index=False)
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5661 entries, 50 to 11132
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               5661 non-null   int64
#  1   videoId          5661 non-null   object
#  2   title            5661 non-null   object
#  3   description      3544 non-null   object
#  4   channelTitle     5661 non-null   object
#  5   publishedAt      5661 non-null   object
#  6   fetchedDate      5661 non-null   object
#  7   business_date    5661 non-null   object
#  8   viewCount        5661 non-null   int64
#  9   likeCount        5661 non-null   int64
#  10  commentCount     5661 non-null   int64
#  11  category         5661 non-null   object
#  12  subscriberCount  5661 non-null   int64
#  13  shortsHashtags   1115 non-null   object
#  14  channelTier      5661 non-null   object
#  15  url              5661 non-null   object
#  16  created_at       1901 non-null   object
# ...

# %% [markdown]
# ---
# 예전에 수집했던 데이터들과 합쳤어서 썸네일 url이 있는 데이터만 가져옴

# %%
df = merge_df.copy()

# %%
# 기존에 수집했던 데이터에서 썸네일 컬럼을 추가하여 새롭게 수집한 데이터가 합쳐서
# 썸네일 컬럼 기준으로 새롭게 수집한 데이터만 가져옴
df = df[~df['thumbnail_url'].isna()].reset_index(drop=True)
df
# Out:
#       id      videoId                                              title  \
# 0      3  3yY6hkwkaOY  Exodus Part 7 — “The Plague of Flies” Shorts  ...
# 1     22  6eVIT1NvSm4                  손오공,칠선공주 2025년 애니메이션 필름 디지털 복원 포럼
# 2    103  QHfIUXvr3xc  Sugar on my 👅 #춤추는서윤 #춤추는곰돌 #댄스 #dance #kpop #...
# 3     36  ksmZypA9aak                               극락 차박의 시작 [카니발 회전시트]
# 4     39  HArxveHj8k0            중고차 딜러가 절대 안 타는 차 #중고차
# ..   ...          ...                                                ...
# 169  181  QZFW_JL8E40  옵션 많은 베스트 셀렉션II 2천만 원대 특가 2021년형 더K9 3.8 4륜 컬러...
# 170  180  hitC3ZG4dTI                           500~600만원대 중고차의 안타까운 현실😇
# 171  192  cI46cR2JasM  🇰🇷 💥 뜻밖의 장면! 여자 골퍼의 대담한 제스처에 K-pop 팬들 충격! #배구 ...
# 172  185  mz_SijmojfU  감자튀기는 고양이 #cat #크림냥 #cute #pets #animals #funn...
# 173  193  DPqVzUZUltA  순간적으로  펴는 요추의 비틀림Instantly stretch the twistin...
#
#                                            description        channelTitle  \
# ...

# %%
df['thumbnail_url']
# Out:
# 0      https://i.ytimg.com/vi/3yY6hkwkaOY/maxresdefau...
# 1      https://i.ytimg.com/vi/6eVIT1NvSm4/maxresdefau...
# 2      https://i.ytimg.com/vi/QHfIUXvr3xc/maxresdefau...
# 3      https://i.ytimg.com/vi/ksmZypA9aak/maxresdefau...
# 4      https://i.ytimg.com/vi/HArxveHj8k0/maxresdefau...
#                              ...
# 169    https://i.ytimg.com/vi/QZFW_JL8E40/maxresdefau...
# 170    https://i.ytimg.com/vi/hitC3ZG4dTI/maxresdefau...
# 171    https://i.ytimg.com/vi/cI46cR2JasM/maxresdefau...
# 172    https://i.ytimg.com/vi/mz_SijmojfU/maxresdefau...
# 173    https://i.ytimg.com/vi/DPqVzUZUltA/maxresdefau...
# Name: thumbnail_url, Length: 174, dtype: object

# %%
df['url']
# Out:
# 0      https://www.youtube.com/watch?v=3yY6hkwkaOY
# 1      https://www.youtube.com/watch?v=6eVIT1NvSm4
# 2      https://www.youtube.com/watch?v=QHfIUXvr3xc
# 3      https://www.youtube.com/watch?v=ksmZypA9aak
# 4      https://www.youtube.com/watch?v=HArxveHj8k0
#                           ...
# 169    https://www.youtube.com/watch?v=QZFW_JL8E40
# 170    https://www.youtube.com/watch?v=hitC3ZG4dTI
# 171    https://www.youtube.com/watch?v=cI46cR2JasM
# 172    https://www.youtube.com/watch?v=mz_SijmojfU
# 173    https://www.youtube.com/watch?v=DPqVzUZUltA
# Name: url, Length: 174, dtype: object

# %% [markdown]
# ---
# 썸네일 이미지 캡션

# %%
import io                           # URL에서 받은 이미지 데이터를 메모리에서 파일처럼 다루기 위해 사용
from PIL import Image               # 이미지열기 ,RGB
import requests                     # 썸네일 URL 다운로드
import torch                        # 텐서연산, GPU, no_grad()등 딥러닝에 사용
import pandas as pd
from tqdm import tqdm
from transformers import BlipProcessor, BlipForConditionalGeneration
# BlipProcessor: 이미지 → 모델 입력 텐서로 바꿔줌  // BlipForConditionalGeneration: 실제로 캡션을 생성하는 시퀀스 생성 모델

# 디바이스 설정
device = "cuda" if torch.cuda.is_available() else "cpu"
print("DEVICE:", device)

# 모델 / 프로세서 한 번만 로드
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base") # 이미지 크기 조정, 텐서 변환, 정규화 등을 알아서 처리
model = BlipForConditionalGeneration.from_pretrained(
    "Salesforce/blip-image-captioning-base"
).to(device)                      # 같은 이름의 BLIP 캡셔닝 모델 가중치를 내려받아 로드 // 이미지 특징을 인코딩해서 문장(캡션)을 생성하는 모델
model.eval()

# URL에서 이미지를 받아서 캡션 생성하는 함수
def caption_image_from_url(url: str, timeout: int = 10) -> str:
    # URL이 비어있거나 NaN이면 바로 빈 문자열 반환
    if not isinstance(url, str) or not url.strip():
        return ""

    try:
        # 이미지 다운로드
        resp = requests.get(url, timeout=timeout)
        resp.raise_for_status() # 200대가 아니면 예외(에러)를 발생 , 404/500에러가 나면 except로 넘어감

        # 바이트 → PIL 이미지
        image = Image.open(io.BytesIO(resp.content)).convert("RGB")

        # BLIP 입력 생성
        # 이미지 리사이즈 / 정규화 / 텐서 변환 처리해서  Pytorch텐서 형식으로 변환
        inputs = processor(image, return_tensors="pt").to(device)

        # 캡션 생성
        # 역전파용 gradient를 계산하지 않도록 // 추론 모드에서 메모리와 속도를 절약하기 위해 필수
        with torch.no_grad():
            out = model.generate(**inputs, max_new_tokens=30)

        # 토크나이저 정보에 따라 다시 글자로 되돌려 줌줌
        # skip_special_tokens => 시작 토큰, 종료 토큰 같은 특수 기호들은 뺌
        caption = processor.decode(out[0], skip_special_tokens=True)

        return caption

    except Exception as e:
        # 문제 생기면 로그만 남기고 빈 문자열 반환
        print(f"[WARN] 캡션 실패: {url} ({e})")
        return ""

# df['thumbnail_url'] 전체에 적용해서 새 컬럼 만들기
tqdm.pandas(desc="thumbnail captioning")
df["thumb_caption"] = df["thumbnail_url"].progress_apply(caption_image_from_url)

# 확인
print(df[["title", "thumbnail_url", "thumb_caption"]].head())
# Out:
# DEVICE: cuda
# thumbnail captioning: 100%|██████████| 174/174 [02:08<00:00,  1.36it/s]
#                                                title  \
# 0  Exodus Part 7 — “The Plague of Flies” Shorts  ...
# 1                  손오공,칠선공주 2025년 애니메이션 필름 디지털 복원 포럼
# 2  Sugar on my 👅 #춤추는서윤 #춤추는곰돌 #댄스 #dance #kpop #...
# 3                               극락 차박의 시작 [카니발 회전시트]
# 4            중고차 딜러가 절대 안 타는 차 #중고차
#
#                                        thumbnail_url  \
# 0  https://i.ytimg.com/vi/3yY6hkwkaOY/maxresdefau...
# 1  https://i.ytimg.com/vi/6eVIT1NvSm4/maxresdefau...
# 2  https://i.ytimg.com/vi/QHfIUXvr3xc/maxresdefau...
# 3  https://i.ytimg.com/vi/ksmZypA9aak/maxresdefau...
# 4  https://i.ytimg.com/vi/HArxveHj8k0/maxresdefau...
#
#                                        thumb_caption
# 0  the bible is shown in this screenshot of the b...
# 1               a man sitting at a table with a cell
# 2   a group of girls standing in front of a building
# ...

# %%
#df[df['thumb_caption']=='a man in a white shirt is holding a cell phone']

# %% [markdown]
# ---
# LLM 파인튜닝

# %%
import pandas as pd
import json
import os

df = df.copy()

# 성능 지표 예시: 구독자 대비 조회수
df["views_per_sub"] = df["viewCount"] / (df["subscriberCount"] + 1)

# 상위 20%만 사용 (원하시는 비율로 조절)
cut = df["views_per_sub"].quantile(0.8)
top = df[df["views_per_sub"] >= cut].copy()

def make_user_prompt(row):
    desc_val = row.get("description")
    if pd.isna(desc_val):
        desc_val = ""
    desc_snip = str(desc_val)[:120]

    return (
        "당신은 한국어 유튜브 마케팅 전문가입니다.\n"
        "다음 정보를 보고 조회수가 잘 나올 만한 제목을 1개만 추천해 주세요.\n\n"
        f"채널 구독자 티어: {row.get('channelTier')}\n"
        f"카테고리: {row.get('category')}\n"
        f"영상 타입: {'Shorts' if row.get('is_short') else 'Long-form'}\n"
        f"썸네일 묘사: {row.get('thumb_caption')}\n"
        f"영상 설명(요약): {desc_snip}\n\n"
        "조건:\n"
        "- 한국어로 작성\n"
        "- 낚시성은 피하되 호기심을 강하게 자극\n"
        "- 30자 이내\n"
        "- 이모지는 최대 1개까지만 사용\n\n"
        "제목:"
    )

out_path = "./Utube_data/LLM_fine-tuning/training_titles.jsonl"

# Ensure the directory exists before writing the file
os.makedirs(os.path.dirname(out_path), exist_ok=True)

with open(out_path, "w", encoding="utf-8") as f:
    for _, row in top.iterrows():
        user_content = make_user_prompt(row)
        assistant_content = row["title"]

        record = {
            "messages": [
                {"role": "system", "content": "당신은 한국어 유튜브 제목 최적화 전문가입니다."},
                {"role": "user", "content": user_content},
                {"role": "assistant", "content": assistant_content},
            ]
        }

        f.write(json.dumps(record, ensure_ascii=False) + "\n")

print("saved:", out_path)
# Out:
# saved: ./Utube_data/LLM_fine-tuning/training_titles.jsonl

# %%
import os
import json
import torch

from datasets import load_dataset
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    TrainingArguments,
    Trainer,
    DataCollatorForLanguageModeling,
)
from peft import LoraConfig, get_peft_model

# 혹시 이전에 set_grad_enabled(False)를 쓴 적이 있다면 여기서 다시 켜기
torch.set_grad_enabled(True)

# -------------------------------------------------
# 기본 설정
# -------------------------------------------------
MODEL_NAME = "Qwen/Qwen2.5-1.5B-Instruct"
DATA_FILE = "./Utube_data/LLM_fine-tuning/training_titles.jsonl"
OUTPUT_DIR = "./Utube_data/yt_title_lora"
MAX_LEN = 256  # 한 샘플 최대 토큰 길이

use_cuda = torch.cuda.is_available()
device_map = "auto" if use_cuda else "cpu"
dtype = torch.float16 if use_cuda else torch.float32

# -------------------------------------------------
# 토크나이저 / 베이스 모델 로드
# -------------------------------------------------
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, use_fast=True)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=dtype,
    device_map=device_map,
)

# 트레이닝 시에는 use_cache 끄는 것이 좋습니다
model.config.use_cache = False

# -------------------------------------------------
# LoRA 설정
# -------------------------------------------------
lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
)

model = get_peft_model(model, lora_config)
model.print_trainable_parameters()

# 이 줄은 gradient checkpointing 쓸 때만 필요하고,
#    지금은 오히려 그래프를 꼬이게 할 수 있으므로 제거합니다.
# model.enable_input_require_grads()

# -------------------------------------------------
# JSONL 데이터셋 로드
# -------------------------------------------------
raw_dset = load_dataset(
    "json",
    data_files={"train": DATA_FILE},
    split="train",
)

# -------------------------------------------------
# chat_template + 토크나이즈
# -------------------------------------------------
def tokenize_function(examples):
    texts = [
        tokenizer.apply_chat_template(
            msgs,
            tokenize=False,
            add_generation_prompt=False,
        )
        for msgs in examples["messages"]
    ]

    batch = tokenizer(
        texts,
        padding="max_length",
        truncation=True,
        max_length=MAX_LEN,
    )

    batch["labels"] = batch["input_ids"].copy()
    return batch


tokenized = raw_dset.map(
    tokenize_function,
    batched=True,
    remove_columns=raw_dset.column_names,
)

# -------------------------------------------------
# 데이터 콜레이터
# -------------------------------------------------
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False,
)

# -------------------------------------------------
# 학습 설정
# -------------------------------------------------
training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    per_device_train_batch_size=1,
    gradient_accumulation_steps=16,
    num_train_epochs=3,
    learning_rate=2e-4,
    fp16=use_cuda,
    logging_steps=50,
    save_steps=500,
    save_total_limit=3,
    # Colab에서는 기본적으로 gradient_checkpointing=False 이라서
    # 따로 enable_input_require_grads 호출이 필요 없습니다.
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized,
    data_collator=data_collator,
)

trainer.train()

trainer.save_model(OUTPUT_DIR)
tokenizer.save_pretrained(OUTPUT_DIR)
print("Saved LoRA adapter and tokenizer to:", OUTPUT_DIR)
# Out:
# trainable params: 2,179,072 || all params: 1,545,893,376 || trainable%: 0.1410
# Map:   0%|          | 0/35 [00:00<?, ? examples/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
#     <div>
#
#       <progress value='9' max='9' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9/9 00:38, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Saved LoRA adapter and tokenizer to: ./Utube_data/yt_title_lora

# %%
import torch
# 텐서 연산과 디바이스 관리에 사용
from transformers import AutoTokenizer, AutoModelForCausalLM
# 모델 이름만 주면 그에 맞는 토크나이저를 자동으로 불러오는 클래스
# 왼쪽에서 오른쪽으로 텍스트를 생성하는 언어모델을 자동으로 불러오는 클래스
from peft import PeftModel
# oRA 같은 PEFT 어댑터를 베이스 모델에 합쳐서 사용하는 래퍼 모델


# 허깅페이스 gpt
BASE_MODEL = "Qwen/Qwen2.5-1.5B-Instruct"
ADAPTER_DIR = "./Utube_data/yt_title_lora"

use_cuda = torch.cuda.is_available()
device_map = "auto" if use_cuda else "cpu"
dtype = torch.float16 if use_cuda else torch.float32

# 토크나이저
tokenizer = AutoTokenizer.from_pretrained(ADAPTER_DIR, use_fast=True)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token


# 베이스 모델 + LoRA 어댑터 로드
base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    torch_dtype=dtype,
    device_map=device_map,
)

# 모델 두개 합친것 (Qwen + 내 데이터의 LoRA)
model = PeftModel.from_pretrained(base_model, ADAPTER_DIR)
model.eval()

print("loaded LoRA model from", ADAPTER_DIR)
# Out:
# loaded LoRA model from ./Utube_data/yt_title_lora

# %%
def build_messages(row):

    desc = row.get("description")
    if desc is None or (isinstance(desc, float) and pd.isna(desc)):
        desc_snip = ""
    else:
        desc_snip = str(desc)[:120]

    # 설명란 없으면 공백 너무 길면 120자까지

    thumb = row.get("thumb_caption")
    if thumb is None or (isinstance(thumb, float) and pd.isna(thumb)):
        thumb_txt = "정보 없음"
    else:
        thumb_txt = str(thumb)


    channel_tier = row.get("channelTier", "Unknown")
    category = row.get("category", "Unknown")
    is_short = bool(row.get("is_short", False))

    user_content = (
        "당신은 한국어 유튜브 마케팅 전문가입니다.\n"
        "다음 정보를 보고 조회수가 잘 나올 만한 제목을 1개만 추천해 주세요.\n\n"
        f"채널 구독자 티어: {channel_tier}\n"
        f"카테고리: {category}\n"
        f"영상 타입: {'Shorts' if is_short else 'Long-form'}\n"
        f"썸네일 묘사: {thumb_txt}\n"
        f"영상 설명(요약): {desc_snip}\n\n"
        "조건:\n"
        "- 한국어로 작성\n"
        "- 낚시성은 피하되 호기심을 강하게 자극\n"
        "- 20자 이내\n"
        "- 이모지는 최대 1개까지만 사용\n\n"
        "제목:"
    )

    messages = [
        {"role": "system", "content": "당신은 한국어 유튜브 제목 최적화 전문가입니다."},
        {"role": "user", "content": user_content},
    ]
    return messages


def generate_title_for_row(row, max_new_tokens=32, temperature=0.7, top_p=0.9):
    messages = build_messages(row)

    # chat 템플릿 적용해서 프롬프트 문자열 만들기
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,  # assistant 차례라고 알려줌
    )

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
    )
    inputs = {k: v.to(model.device) for k, v in inputs.items()}


    with torch.no_grad():
        # 토큰들을 자동으로 생성해 주는 고수준 메서드
        output_ids = model.generate(
            **inputs,                           # 토크나이저가 만들어 준 입력 텐서들을 그대로 모델에 전달
            max_new_tokens=max_new_tokens,      # 새로 생성할 토큰의 최대 개수를 지정
            do_sample=True,                     # 고정적으로 높은 토큰만 나오는게 아닌 계속 다른 결과
            top_p=top_p,

            temperature=temperature,
            # 1.0이면 원래 확률 분포 그대로 사용
            # 1.0보다 크면 분포를 더 평평하게 만들어 덜 확률 높은 토큰도 뽑힐 가능성이 커짐
            # 1.0보다 작으면 분포를 더 뾰족하게 만들어 가장 유력한 후보 쪽으로 더 강하게 쏠림

            pad_token_id=tokenizer.eos_token_id,    # eos padding ( 길이가 부족하면 eos(끝)을 채워서 padding )
        )

    # 모델이 생성한 제목
    full_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    # "제목:" 이후만 잘라서 실제 제목만 뽑기
    idx = full_text.rfind("제목:")      # "제목:"을 찾지 못하면 -1
    if idx != -1:
        title = full_text[idx + len("제목:"):].strip()
    else:
        # 혹시 못 찾으면 전체 텍스트에서 마지막 줄만 사용
        title = full_text.strip().splitlines()[-1].strip()

    # assistant 제거 ( 출력할때 assistant도 같이 출력 됨 )
    t = title.lstrip()
    for assistants in ["assistant", "Assistant", "assistant:", "Assistant:"]:
        if t.startswith(assistants):                         # assistants 리스트 4개중 하나로 시작한다면
            t = t[len(assistants):].lstrip(" :-\u3000")      # 길이만큼 슬라이싱하고 공백, :, -, 삭제제
            break
    title = t

    return title

# %%
def generate_n_titles_for_row(row, n=5,
                              max_new_tokens=32,
                              temperature=0.7,
                              top_p=0.9):
    titles = []
    for i in range(n):
        t = generate_title_for_row(
            row,
            max_new_tokens=max_new_tokens,
            temperature=temperature,
            top_p=top_p,
        )
        titles.append(t)
    return titles

# %% [markdown]
# ---
# - 결과

# %%
# 인덱스 n번 행
title_df = df.iloc[160]

row = title_df.to_dict()
gen_title = generate_title_for_row(row)
print("원래 제목 :", title_df["title"])
print("추천 제목 :", gen_title)
# Out:
# 원래 제목 : 얼음의 숨결 – 시네마틱 댄스8K  리얼리즘, 얼음 위에 피어난 감정의 예술#8k 리얼리즘 #カピバラさん #sports #tranding #shorts #figureskating
# 추천 제목 :
# 1. "얼음 위, 두 영혼이 마주 선"
# 2. "카피바라, 얼음의 숨결 공연 -

# %% [markdown]
# ---

# %%
title_df = df.iloc[160]
row = title_df.to_dict()

cand_titles = generate_n_titles_for_row(row, n=5)

print("원래 제목 :", title_df["title"])
print("추천 제목들:")
for i, t in enumerate(cand_titles, 1):
    print(f"{i}. {t}")
# Out:
# 원래 제목 : 얼음의 숨결 – 시네마틱 댄스8K  리얼리즘, 얼음 위에 피어난 감정의 예술#8k 리얼리즘 #カピバラさん #sports #tranding #shorts #figureskating
# 추천 제목들:
# 1.
# "아름다운 얼음에서 두 영혼이 마주침"
# 2.
# "아이스크림위에서 떠오르는 감정의 예술 - 8K 리얼리즘 댄스"
# 3.
# "얼음 위에서 만나는 두 영혼 - 8K 실감미러 스포츠 팔레트"
# 4.
# "냉각된 감정의 아름다운 춤 - 얼음 위의 사랑 이야기"
# 5.
# "두 영혼의 격동 얼음 연습 – 8K 실시간 리얼리즘!"
